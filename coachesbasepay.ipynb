# %%
import pandas as pd
# %matplotlib inline

import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r'C:\Users\student\Documents\coachesbasesalary.csv')

# %%
df
# Out:
#       RK                SCHOOL     CONF             COACH  SCHOOL_PAY  \
# 0      1               Clemson      ACC      Dabo Swinney   9255000.0
# 1      2               Alabama      SEC        Nick Saban   8707000.0
# 2      3              Michigan  Big Ten      Jim Harbaugh   7504000.0
# 3      4             Texas A&M      SEC      Jimbo Fisher   7500000.0
# 4      5               Georgia      SEC       Kirby Smart   6703600.0
# 5      6                Auburn      SEC       Gus Malzahn   6800000.0
# 6      7                 Texas   Big 12        Tom Herman   6750000.0
# 7      8                Purdue  Big Ten        Jeff Brohm   6600000.0
# 8      9              Oklahoma   Big 12     Lincoln Riley   6384462.0
# 9     10               Florida      SEC        Dan Mullen   6070000.0
# 10    11            Penn State  Big Ten    James Franklin   5650000.0
# 11    12          Northwestern  Big Ten    Pat Fitzgerald   5144937.0
# ...

# %%
Finaldf=(df['SCHOOL_PAY']/df['Wins'])

# %%
# Calculate the amount of money the school pays for each win to their head coach
df['WinsPerDollar']=(df['SCHOOL_PAY']/df['Wins'])

# %%
pd.options.display.float_format = '{:.5f}'.format

# %%
df
# Out:
#       RK                SCHOOL     CONF             COACH    SCHOOL_PAY  \
# 0      1               Clemson      ACC      Dabo Swinney 9255000.00000
# 1      2               Alabama      SEC        Nick Saban 8707000.00000
# 2      3              Michigan  Big Ten      Jim Harbaugh 7504000.00000
# 3      4             Texas A&M      SEC      Jimbo Fisher 7500000.00000
# 4      5               Georgia      SEC       Kirby Smart 6703600.00000
# 5      6                Auburn      SEC       Gus Malzahn 6800000.00000
# 6      7                 Texas   Big 12        Tom Herman 6750000.00000
# 7      8                Purdue  Big Ten        Jeff Brohm 6600000.00000
# 8      9              Oklahoma   Big 12     Lincoln Riley 6384462.00000
# 9     10               Florida      SEC        Dan Mullen 6070000.00000
# 10    11            Penn State  Big Ten    James Franklin 5650000.00000
# 11    12          Northwestern  Big Ten    Pat Fitzgerald 5144937.00000
# ...

# %%
# sorting values from least to greatest
df=df.sort_values(by=['WinsPerDollar'], ascending=True).head(180)

# %%
df
# Out:
#       RK                SCHOOL     CONF            COACH    SCHOOL_PAY  \
# 94    95     Appalachian State   S-Belt  Eliah Drinkwitz  750000.00000
# 107  108                Hawaii      MWC    Nick Rolovich  600004.00000
# 118  119            Kent State      MAC       Sean Lewis  440000.00000
# 111  112          Miami (Ohio)      MAC     Chuck Martin  533360.00000
# 96    97        Louisiana Tech     CUSA       Skip Holtz  700000.00000
# 113  114                Nevada      MWC      Jay Norvell  500000.00000
# 115  116  Southern Mississippi     CUSA       Jay Hopson  500000.00000
# 121  122      Coastal Carolina   S-Belt   Jamey Chadwell  360000.00000
# 104  105               Buffalo      MAC    Lance Leipold  615000.00000
# 120  121             UL Monroe   S-Belt      Matt Viator  390000.00000
# 116  117      Eastern Michigan      MAC  Chris Creighton  470000.00000
# 87    88          UL Lafayette   S-Belt     Billy Napier  875000.00000
# ...

# %%
df.head(130)
# Out:
#       RK                SCHOOL     CONF            COACH    SCHOOL_PAY  \
# 94    95     Appalachian State   S-Belt  Eliah Drinkwitz  750000.00000
# 107  108                Hawaii      MWC    Nick Rolovich  600004.00000
# 118  119            Kent State      MAC       Sean Lewis  440000.00000
# 111  112          Miami (Ohio)      MAC     Chuck Martin  533360.00000
# 96    97        Louisiana Tech     CUSA       Skip Holtz  700000.00000
# 113  114                Nevada      MWC      Jay Norvell  500000.00000
# 115  116  Southern Mississippi     CUSA       Jay Hopson  500000.00000
# 121  122      Coastal Carolina   S-Belt   Jamey Chadwell  360000.00000
# 104  105               Buffalo      MAC    Lance Leipold  615000.00000
# 120  121             UL Monroe   S-Belt      Matt Viator  390000.00000
# 116  117      Eastern Michigan      MAC  Chris Creighton  470000.00000
# 87    88          UL Lafayette   S-Belt     Billy Napier  875000.00000
# ...

# %%
onedf=df.head(10)

# %%
onedf = df.groupby('COACH')['WinsPerDollar']

# %%
df.replace([np.inf, -np.inf], np.nan)
# Out:
#       RK                SCHOOL     CONF            COACH    SCHOOL_PAY  \
# 94    95     Appalachian State   S-Belt  Eliah Drinkwitz  750000.00000
# 107  108                Hawaii      MWC    Nick Rolovich  600004.00000
# 118  119            Kent State      MAC       Sean Lewis  440000.00000
# 111  112          Miami (Ohio)      MAC     Chuck Martin  533360.00000
# 96    97        Louisiana Tech     CUSA       Skip Holtz  700000.00000
# 113  114                Nevada      MWC      Jay Norvell  500000.00000
# 115  116  Southern Mississippi     CUSA       Jay Hopson  500000.00000
# 121  122      Coastal Carolina   S-Belt   Jamey Chadwell  360000.00000
# 104  105               Buffalo      MAC    Lance Leipold  615000.00000
# 120  121             UL Monroe   S-Belt      Matt Viator  390000.00000
# 116  117      Eastern Michigan      MAC  Chris Creighton  470000.00000
# 87    88          UL Lafayette   S-Belt     Billy Napier  875000.00000
# ...

# %%
df['WinsPerDollar'].mean()
# Out:
# inf

# %%
#filter out all the coaches who accepted new jobs. These are the best available coaches for next season
BestCoaches=df[(df['Promoted'] == 'No')].head(130)

# %%
BestCoaches
# Out:
#       RK                 SCHOOL     CONF            COACH    SCHOOL_PAY  \
# 118  119             Kent State      MAC       Sean Lewis  440000.00000
# 111  112           Miami (Ohio)      MAC     Chuck Martin  533360.00000
# 96    97         Louisiana Tech     CUSA       Skip Holtz  700000.00000
# 113  114                 Nevada      MWC      Jay Norvell  500000.00000
# 115  116   Southern Mississippi     CUSA       Jay Hopson  500000.00000
# 121  122       Coastal Carolina   S-Belt   Jamey Chadwell  360000.00000
# 104  105                Buffalo      MAC    Lance Leipold  615000.00000
# 120  121              UL Monroe   S-Belt      Matt Viator  390000.00000
# 116  117       Eastern Michigan      MAC  Chris Creighton  470000.00000
# 87    88           UL Lafayette   S-Belt     Billy Napier  875000.00000
# 101  102       Central Michigan      MAC     Jim McElwain  640900.00000
# 110  111          Georgia State   S-Belt    Shawn Elliott  594000.00000
# ...

# %%
newdf=df.replace([np.inf, -np.inf], np.nan).dropna(subset=["WinsPerDollar"], how="all")

# %%
newdf['WinsPerDollar'].mean()
# Out:
# 456814.5015555841

# %%
ConferenceAverageSpendingPerWin=newdf.groupby('CONF')['WinsPerDollar'].mean()

# %%
ConferenceAverageSpendingPerWin
# Out:
# CONF
# AAC       485818.74946
# ACC       555982.99023
# Big 12    640787.56870
# Big Ten   770352.55106
# CUSA      248387.12612
# INDEP     332455.15152
# MAC       104718.97879
# MWC       208710.75758
# Pac-12    509332.36976
# S-Belt    125902.94289
# SEC       782188.13276
# Name: WinsPerDollar, dtype: float64

# %%
Sorted = df.sort_values('WinsPerDollar')

# %%
Sorted.head(200)
# Out:
#       RK                SCHOOL     CONF            COACH    SCHOOL_PAY  \
# 94    95     Appalachian State   S-Belt  Eliah Drinkwitz  750000.00000
# 107  108                Hawaii      MWC    Nick Rolovich  600004.00000
# 118  119            Kent State      MAC       Sean Lewis  440000.00000
# 111  112          Miami (Ohio)      MAC     Chuck Martin  533360.00000
# 96    97        Louisiana Tech     CUSA       Skip Holtz  700000.00000
# 113  114                Nevada      MWC      Jay Norvell  500000.00000
# 115  116  Southern Mississippi     CUSA       Jay Hopson  500000.00000
# 121  122      Coastal Carolina   S-Belt   Jamey Chadwell  360000.00000
# 104  105               Buffalo      MAC    Lance Leipold  615000.00000
# 120  121             UL Monroe   S-Belt      Matt Viator  390000.00000
# 116  117      Eastern Michigan      MAC  Chris Creighton  470000.00000
# 87    88          UL Lafayette   S-Belt     Billy Napier  875000.00000
# ...

# %%
BigTen=df[(df['CONF'] == 'Big Ten')].head(16)

# %%
SEC=df[(df['CONF'] == 'SEC')].head(16)

# %%
Pac12=df[(df['CONF'] == 'Pac-12')].head(16)

# %%
Pac12f=Pac12.groupby('COACH')['WinsPerDollar'].mean()

# %%
Pac12f.plot.bar(color=['blue'])
plt.title('WinsPerDollar')
plt.ylabel('DollarsPerWin')
plt.xlabel('Coach')
# Out:
# Text(0.5, 0, 'Coach')

# %%
Big12=df[(df['CONF'] == 'Big 12')].head(15)

# %%
Big12f=Big12.groupby('COACH')['WinsPerDollar'].mean()

# %%
Big12f
# Out:
# COACH
# Chris Klieman    287500.00000
# Gary Patterson   980155.20000
# Les Miles        925000.00000
# Lincoln Riley    532038.50000
# Matt Campbell    514285.71429
# Matt Rhule       373521.27273
# Matt Wells       700000.00000
# Mike Gundy       640625.00000
# Neal Brown       611000.00000
# Tom Herman       843750.00000
# Name: WinsPerDollar, dtype: float64

# %%
Big12f.plot.bar(color=['blue'])
plt.title('WinsPerDollar')
plt.ylabel('DollarsPerWin')
plt.xlabel('Coach')
# Out:
# Text(0.5, 0, 'Coach')

# %%
SECF=SEC.groupby('COACH')['WinsPerDollar'].mean()

# %%
SECF
# Out:
# COACH
# Barry Odom       508333.33333
# Chad Morris     2000000.00000
# Dan Mullen       551818.18182
# Derek Mason     1122748.00000
# Ed Orgeron       266666.66667
# Gus Malzahn      755555.55556
# Jeremy Pruitt    480750.00000
# Jimbo Fisher     937500.00000
# Joe Moorhead     508333.33333
# Kirby Smart      558633.33333
# Mark Stoops      593750.00000
# Matt Luke        775000.00000
# Nick Saban       791545.45455
# Will Muschamp   1100000.00000
# Name: WinsPerDollar, dtype: float64

# %%
BIGTENF=BigTen.groupby('COACH')['WinsPerDollar'].mean()

# %%
BIGTENF
# Out:
# COACH
# Chris Ash        1150000.00000
# James Franklin    513636.36364
# Jeff Brohm       1650000.00000
# Jim Harbaugh      833777.77778
# Kirk Ferentz      480000.00000
# Lovie Smith       666666.66667
# Mark Dantonio     628491.00000
# Mike Locksley     833333.33333
# P.J. Fleck        327272.72727
# Pat Fitzgerald   1714979.00000
# Paul Chryst       415000.00000
# Ryan Day          346153.84615
# Scott Frost      1000000.00000
# Tom Allen         225625.00000
# Name: WinsPerDollar, dtype: float64

# %%
BIGTENF.plot.bar(color=['blue'])
plt.title('WinsPerDollar')
plt.ylabel('DollarsPerWin')
plt.xlabel('Coach')
# Out:
# Text(0.5, 0, 'Coach')

# %%
SECF.plot.bar(color=['blue'])
plt.title('WinsPerDollar')
plt.ylabel('DollarsPerWin')
plt.xlabel('Coach')
# Out:
# Text(0.5, 0, 'Coach')

# %%
AAC=df[(df['CONF'] == 'AAC')].head(16)

# %%
AACF=AAC.groupby('COACH')['WinsPerDollar'].mean()

# %%
AACF.plot.bar(color=['blue'])
plt.title('WinsPerDollar')
plt.ylabel('DollarsPerWin')
plt.xlabel('Coach')
# Out:
# Text(0.5, 0, 'Coach')

# %%
MWC=df[(df['CONF'] == 'MWC')].head(16)

# %%
MWCF=MWC.groupby('COACH')['WinsPerDollar'].mean()

# %%
MWCF.plot.bar(color=['blue'])
plt.title('WinsPerDollar')
plt.ylabel('DollarsPerWin')
plt.xlabel('Coach')
# Out:
# Text(0.5, 0, 'Coach')

# %%
SBelt=df[(df['CONF'] == 'S-Belt')].head(16)

# %%
SBelttF=SBelt.groupby('COACH')['WinsPerDollar'].mean()

# %%
SBelttF.plot.bar(color=['blue'])
plt.title('WinsPerDollar')
plt.ylabel('DollarsPerWin')
plt.xlabel('Coach')
# Out:
# Text(0.5, 0, 'Coach')

# %%
MAC=df[(df['CONF'] == 'MAC')].head(16)

# %%
MACF=MAC.groupby('COACH')['WinsPerDollar'].mean()

# %%
MACF.plot.bar(color=['blue'])
plt.title('WinsPerDollar')
plt.ylabel('DollarsPerWin')
plt.xlabel('Coach')
# Out:
# Text(0.5, 0, 'Coach')

# %%
CUSA=df[(df['CONF'] == 'CUSA')].head(16)

# %%
CUSAF=CUSA.groupby('COACH')['WinsPerDollar'].mean()

# %%
CUSAF.plot.bar(color=['blue'])
plt.title('WinsPerDollar')
plt.ylabel('DollarsPerWin')
plt.xlabel('Coach')
# Out:
# Text(0.5, 0, 'Coach')
